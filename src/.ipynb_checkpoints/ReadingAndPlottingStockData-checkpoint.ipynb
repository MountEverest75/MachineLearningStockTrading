# %% [markdown]
# # 1. Preliminary Stock Analysis - Pandas Library and Yahoo Finance CSV Files

# %%
import pandas as pd

# %%
df_amzn = pd.read_csv("../data/AMZN.csv")
print(df_amzn)
# Out:
#             Date         Open         High          Low        Close  \
# 0     1997-05-15     2.437500     2.500000     1.927083     1.958333
# 1     1997-05-16     1.968750     1.979167     1.708333     1.729167
# 2     1997-05-19     1.760417     1.770833     1.625000     1.708333
# 3     1997-05-20     1.729167     1.750000     1.635417     1.635417
# 4     1997-05-21     1.635417     1.645833     1.375000     1.427083
# ...          ...          ...          ...          ...          ...
# 5730  2020-02-24  2003.180054  2039.300049  1987.969971  2009.290039
# 5731  2020-02-25  2026.420044  2034.599976  1958.420044  1972.739990
# 5732  2020-02-26  1970.280029  2014.670044  1960.449951  1979.589966
# 5733  2020-02-27  1934.380005  1975.000000  1882.760010  1884.300049
# 5734  2020-02-28  1814.630005  1889.760010  1811.130005  1883.750000
#
#         Adj Close    Volume
# 0        1.958333  72156000
# 1        1.729167  14700000
# 2        1.708333   6106800
# 3        1.635417   5467200
# 4        1.427083  18853200
# ...           ...       ...
# 5730  2009.290039   6547000
# 5731  1972.739990   6219100
# 5732  1979.589966   5224600
# 5733  1884.300049   8144000
# 5734  1883.750000   9481000
#
# [5735 rows x 7 columns]

# %%
print(df_amzn.tail())
print(df_amzn.head())
# Out:
#             Date         Open         High          Low        Close  \
# 5730  2020-02-24  2003.180054  2039.300049  1987.969971  2009.290039
# 5731  2020-02-25  2026.420044  2034.599976  1958.420044  1972.739990
# 5732  2020-02-26  1970.280029  2014.670044  1960.449951  1979.589966
# 5733  2020-02-27  1934.380005  1975.000000  1882.760010  1884.300049
# 5734  2020-02-28  1814.630005  1889.760010  1811.130005  1883.750000
#
#         Adj Close   Volume
# 5730  2009.290039  6547000
# 5731  1972.739990  6219100
# 5732  1979.589966  5224600
# 5733  1884.300049  8144000
# 5734  1883.750000  9481000
#          Date      Open      High       Low     Close  Adj Close    Volume
# 0  1997-05-15  2.437500  2.500000  1.927083  1.958333   1.958333  72156000
# 1  1997-05-16  1.968750  1.979167  1.708333  1.729167   1.729167  14700000
# 2  1997-05-19  1.760417  1.770833  1.625000  1.708333   1.708333   6106800
# 3  1997-05-20  1.729167  1.750000  1.635417  1.635417   1.635417   5467200
# 4  1997-05-21  1.635417  1.645833  1.375000  1.427083   1.427083  18853200

# %%
df_jnj = pd.read_csv("../data/JNJ.csv")
print(df_jnj)
print(df_jnj.tail())
print(df_jnj.head())
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 0      1962-01-02    0.000000    0.223380    0.222222    0.223380    0.000001
# 1      1962-01-03    0.000000    0.221065    0.219907    0.219907    0.000001
# 2      1962-01-04    0.000000    0.221065    0.217593    0.217593    0.000001
# 3      1962-01-05    0.000000    0.215856    0.214120    0.214120    0.000001
# 4      1962-01-08    0.000000    0.212384    0.210648    0.210648    0.000001
# ...           ...         ...         ...         ...         ...         ...
# 14635  2020-02-24  146.500000  149.000000  145.250000  145.910004  145.910004
# 14636  2020-02-25  145.990005  146.750000  143.830002  144.649994  144.649994
# 14637  2020-02-26  145.350006  146.220001  143.589996  143.679993  143.679993
# 14638  2020-02-27  142.559998  144.770004  138.949997  139.119995  139.119995
# 14639  2020-02-28  135.360001  137.289993  130.820007  134.479996  134.479996
#
#          Volume
# 0             0
# 1        345600
# 2        216000
# 3        129600
# 4        172800
# ...         ...
# 14635  10588900
# 14636  10529000
# 14637  10093800
    base_dir = "../data/"
    df = pd.read_csv(os.path.join(base_dir, "{}.csv".format(str(ticker_symbol))))
    return df['Close'].max()

def get_mean_volume(symbol):
    """Return the mean volume for stock indicated by symbol.
    
    Note: Data for a stock is stored in file: data/<symbol>.csv
    """
    base_dir = "../data/"
    #print(os.path.join(base_dir, "{}.csv".format(str(ticker))))
    df = pd.read_csv(os.path.join(base_dir, "{}.csv".format(str(symbol))))  # read in data
    # TODO: Compute and return the mean volume for this stock
    return df['Volume'].mean()


for symbol in ['AMZN', 'JNJ']:
    print("Max Close:",symbol,get_max_close(symbol))
    print("Mean Volume:",symbol,get_mean_volume(symbol))
# Out:
# Max Close: AMZN 2170.219971
# Mean Volume: AMZN 7557115.239755885
# Max Close: JNJ 153.990005
# Mean Volume: JNJ 5467730.676229509

# %%
import matplotlib.pyplot as plt

# %%
def plot_price_history(ticker):
    """Plot price history in reverse order"""
    base_dir = "../data/"
    df = pd.read_csv(os.path.join(base_dir, "{}.csv".format(ticker)))
    df['Adj Close'].plot()
    plt.show() #call to show plots
    
for symbol in ['AMZN', 'JNJ']:
    plot_price_history(symbol)

# %%
def plot_high_history(ticker):
    """Plot price history in reverse order"""
    base_dir = "../data/"
    df = pd.read_csv(os.path.join(base_dir, "{}.csv".format(ticker)))
    #print(df['High'])
    df['High'].plot()
    plt.show() #call to show plots
    
for symbol in ['AMZN', 'JNJ', 'SPY']:
    plot_high_history(symbol)

# %%
def plot_two_columns(ticker):
    """Plot two portions of data"""
    base_dir = "../data/"
    df = pd.read_csv(os.path.join(base_dir, "{}.csv".format(ticker)))
    df[['Close', 'Adj Close']].plot()
    plt.show()

for symbol in ['AMZN', 'JNJ']:
    plot_two_columns(symbol)

# %%
# Identified a bug in the moving average calculation. It should consider last 200 entries to calculate not first 200.
# Date: 2019-06-15
def get_moving_average(ticker, duration):
    """Example to get 200 day moving average, pass duration=200 and ticker symbol=JNJ or any stock"""
    base_dir = "../data/"
    df = pd.read_csv(os.path.join(base_dir, "{}.csv".format(ticker)))
    #df = df[1:201] 
    #return df['Close'].mean()
    return df['Close'][-200:].mean()
    

for symbol in ['AAPL','ABBV','AMZN','BA','BLK','COST','CRM','CRWD','FDX','GOOG','JNJ','JPM','MRVL','MSFT','NFLX','OKTA','TWLO','V','SPY']:
    duration=200
    print("Moving Average for: ", duration, "days. For ticker:", symbol, get_moving_average(symbol,duration))
# Out:
# Moving Average for:  200 days. For ticker: AAPL 241.83304960500004
# Moving Average for:  200 days. For ticker: ABBV 78.6517498
# Moving Average for:  200 days. For ticker: AMZN 1849.85079892
# Moving Average for:  200 days. For ticker: BA 349.8252992199999
# Moving Average for:  200 days. For ticker: BLK 471.91914946000014
# Moving Average for:  200 days. For ticker: COST 287.14719972
# Moving Average for:  200 days. For ticker: CRM 159.92585004
# Moving Average for:  200 days. For ticker: CRWD 64.85041453038677
# Moving Average for:  200 days. For ticker: FDX 157.717499915
# Moving Average for:  200 days. For ticker: GOOG 1258.1792993399993
# Moving Average for:  200 days. For ticker: JNJ 137.27760020499997
# Moving Average for:  200 days. For ticker: JPM 121.77574996499996
# Moving Average for:  200 days. For ticker: MRVL 24.957649979999996
# Moving Average for:  200 days. For ticker: MSFT 145.99535007999992
# Moving Average for:  200 days. For ticker: NFLX 322.9509489300001
# Moving Average for:  200 days. For ticker: OKTA 121.75880014499995
# Moving Average for:  200 days. For ticker: TWLO 120.13129985999998
# Moving Average for:  200 days. For ticker: V 181.43829985500008
# Moving Average for:  200 days. For ticker: SPY 301.62799912

# %%
# Bug fixes to join data frames. Dynamically fetch the start date of trading before joining and indexing closing prices by date
from datetime import datetime, date

def get_stock_datadir(ticker,base_dir="../data/"):
    #Return CSV file given ticker symbol
    return os.path.join(base_dir, "{}.csv".format(str(ticker)))

def get_date_range_df(ticker):
    normal_df = pd.read_csv(get_stock_datadir(ticker))
    start_date = normal_df['Date'].iloc[0]
    #end_date = date(date.today().year, date.today().month, date.today().day) # Gets current record
    end_date = normal_df['Date'].iloc[-1] #Gets the end date from last record
    dates = pd.date_range(start_date, end_date)
    df_dates = pd.DataFrame(index=dates)
    return df_dates
    

def join_data_frames(ticker):
    #Create Dataframe for ticker symbol using Date column as index. Also indicate that dates need to be parsed
    base_dir="../data/"
    df_ticker = pd.read_csv(os.path.join(base_dir, "{}.csv".format(str(ticker))),index_col="Date", parse_dates=True, usecols=['Date', 'Close', 'Adj Close'],na_values=['nan'])
    df_dates = get_date_range_df(ticker)
    df = df_dates.join(df_ticker, how='inner')
    return df
    
    
print("For JNJ:")
print(join_data_frames('JNJ'))
print("For AMZN:")
print(join_data_frames('AMZN'))
# Out:
# For JNJ:
#                  Close   Adj Close
# 1962-01-02    0.223380    0.000001
# 1962-01-03    0.219907    0.000001
# 1962-01-04    0.217593    0.000001
# 1962-01-05    0.214120    0.000001
# 1962-01-08    0.210648    0.000001
# ...                ...         ...
# 2020-02-24  145.910004  145.910004
# 2020-02-25  144.649994  144.649994
# 2020-02-26  143.679993  143.679993
# 2020-02-27  139.119995  139.119995
# 2020-02-28  134.479996  134.479996
#
# [14640 rows x 2 columns]
# For AMZN:
#                   Close    Adj Close
# 1997-05-15     1.958333     1.958333
# 1997-05-16     1.729167     1.729167
# 1997-05-19     1.708333     1.708333
# 1997-05-20     1.635417     1.635417
# 1997-05-21     1.427083     1.427083
# ...                 ...          ...
# 2020-02-24  2009.290039  2009.290039
# 2020-02-25  1972.739990  1972.739990
# 2020-02-26  1979.589966  1979.589966
# 2020-02-27  1884.300049  1884.300049
# 2020-02-28  1883.750000  1883.750000
#
# [5735 rows x 2 columns]

# %%
def join_multiple_tickers(tickers):
    #Create empty data frames with date range
    base_dir = "../data/"
    df_old = pd.DataFrame()
    for symbol in tickers:
        df = get_date_range_df(symbol)
        df_temp = pd.read_csv(os.path.join(base_dir, "{}.csv".format(symbol)), index_col="Date", parse_dates=True, usecols=['Date', 'Adj Close'],na_values=['nan'])
        df_temp = df_temp.rename(columns={'Adj Close': symbol})
        df = df.join(df_temp, how='inner')
        if not df_old.empty:
            df = df_old.join(df,how='inner')
        df_old = df
    df = df.dropna()
    return df

tickers = ['AAPL','ABBV','AMZN','BA','BLK','COST','CRM','CRWD','FDX','GOOG','JNJ','JPM','MRVL','MSFT','NFLX','OKTA','TWLO','V']
#tickers = ['AMZN']
# tickers = ['AMZN']
join_multiple_tickers(tickers)
# Out:
#                   AAPL       ABBV         AMZN          BA         BLK  \
# 2019-06-12  192.419250  75.260849  1855.319946  340.849030  439.706696
# 2019-06-13  192.379593  75.624832  1870.300049  342.646423  441.706940
# 2019-06-14  190.982468  75.375801  1869.670044  340.976715  440.416168
# 2019-06-17  192.121979  75.337471  1886.030029  348.578857  433.666595
# 2019-06-18  196.640396  74.954330  1901.369995  367.299377  442.721863
_values=['nan'])
        df_temp = df_temp.rename(columns={'Adj Close': symbol})
        #print(df_temp)
        df = df.join(df_temp)
    df = df.dropna()
    #if symbol == 'SPY':
        #df = df.dropna(subset=["SPY"])
        
    return df


def test_run():
    # Define a date range
    end_date = date(date.today().year, date.today().month, date.today().day)
    dates = pd.date_range('1950-01-01', end_date)
    #dates = get_date_range_df()

    # Choose stock symbols to read
    symbols = ['AAPL','ABBV','AMZN','BA','BLK','COST','CRM','CRWD','FDX','GOOG','JNJ','JPM','MRVL','MSFT','NFLX','OKTA','TWLO','V']
    
    # Get stock data
    df = get_data(symbols, dates)
    print(df)

#test_run()
symbols = ['AAPL','ABBV','AMZN','BA','BLK','COST','CRM','CRWD','FDX','GOOG','JNJ','JPM','MRVL','MSFT','NFLX','OKTA','TWLO','V']
end_date = date(date.today().year, date.today().month, date.today().day)
dates = pd.date_range('1950-01-01', end_date)
df = get_data(symbols, dates)

# %%
# %matplotlib inline 
#Getting the subset of Data Frame. We use Date Range because its already indexed 
#Both df[] and df.ix[] work
#df2 = df['2017-09-01':'2017-10-01']
#df2 = df.ix['2017-09-01':'2017-10-01']
# end_date = date(date.today().year, date.today().month, date.today().day)
# df2 = df.loc['1900-01-01': end_date]
# df3 = df2[['AMZN','JNJ','SPY']]
# print(df3)
# df2.plot()
df4 = df
df.plot()

# %%
#Normalize Price Data to start all prices at 1.0. Also revised to use loc and iloc instead of ix method for data frames
#Option 1
#df4 = df4 / df4.ix[0]
df4 = df4 / df4.iloc[0]
print(df4)
#df5 = df4

#Option 2
#df5 = df5 / df5.ix[0, :]
# df5 = df5 / df5.iloc[0, :]
# print(df5)
#print(df4 == df5)
# Out:
#                  SPY      AAPL      ABBV      AMZN        BA       BLK  \
# 2019-06-12  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2019-06-13  1.004126  0.999794  1.004836  1.008074  1.005273  1.004549
# 2019-06-14  1.003017  0.992533  1.001527  1.007735  1.000375  1.001614
# 2019-06-17  1.003398  0.998455  1.001018  1.016552  1.022678  0.986263
# 2019-06-18  1.013905  1.021937  0.995927  1.024821  1.077601  1.006857
# ...              ...       ...       ...       ...       ...       ...
# 2020-01-31  1.131747  1.604711  1.076522  1.082681  0.928234  1.199322
# 2020-02-03  1.140154  1.600303  1.093530  1.080245  0.921613  1.205531
# 2020-02-04  1.157532  1.653135  1.120902  1.104753  0.927271  1.217266
# 2020-02-05  1.170899  1.666616  1.151063  1.099471  0.961132  1.236006
# 2020-02-06  1.174839  1.686110  1.158371  1.105055  0.995780  1.261454
#
#                 COST       CRM      CRWD       FDX      GOOG       JNJ  \
# 2019-06-12  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2019-06-13  1.009641  1.000397  1.164828  1.026647  1.010900  0.993154
# 2019-06-14  1.011352  0.991605  1.106207  1.019706  1.007725  0.988778
# 2019-06-17  1.016328  0.993456  1.207069  1.014563  1.014364  0.984190
# 2019-06-18  1.021420  0.995439  1.318966  1.030799  1.024670  0.989766
# ...              ...       ...       ...       ...       ...       ...
# 2020-01-31  1.192944  1.205116  1.053276  0.907199  1.331653  1.065956
# 2020-02-03  1.179200  1.225674  1.053103  0.902181  1.379664  1.075265
# 2020-02-04  1.190523  1.244976  1.095776  0.925200  1.343574  1.085504
# 2020-02-05  1.206337  1.226137  1.065776  0.940504  1.344651  1.102617
# 2020-02-06  1.215376  1.234334  1.072241  0.932225  1.370649  1.099323
#
#                  JPM      MRVL      MSFT      NFLX      OKTA      TWLO  \
# 2019-06-12  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2019-06-13  1.002471  1.008313  1.006312  0.993836  1.005709  0.985813
# 2019-06-14  1.005033  0.990441  1.007301  0.983129  0.994908  0.979593
# 2019-06-17  0.999542  0.985869  1.010343  1.014643  0.986035  0.983367
# 2019-06-18  1.013178  1.020366  1.027911  1.033453  0.993210  0.994409
# ...              ...       ...       ...       ...       ...       ...
# 2020-01-31  1.237554  1.006467  1.303354  0.998640  0.987964  0.868964
# 2020-02-03  1.246997  1.013584  1.335128  1.036000  0.997994  0.895800
# 2020-02-04  1.264949  1.036611  1.379076  1.067861  1.039735  0.921797
# 2020-02-05  1.286453  1.081827  1.377392  1.069771  1.000463  0.888602
# 2020-02-06  1.286641  1.078059  1.405950  1.061900  1.003703  0.823747
#
#                    V
# 2019-06-12  1.000000
# 2019-06-13  0.986946
# 2019-06-14  0.988752
# 2019-06-17  0.988170
# 2019-06-18  0.986538
# ...              ...
# 2020-01-31  1.163185
# 2020-02-03  1.173941
# 2020-02-04  1.190018
# 2020-02-05  1.185633
# 2020-02-06  1.186978
#
# [166 rows x 19 columns]

# %%
def plot_data(df, title="Stock Prices"):
    """Plot Data Frame"""
    #Commented statements provide basic plotting
    #Send Title to the graph. Also the output of df.plot() is a handler "df_plot" to add x and y axis labels
    df_plot = df.plot(title=title)
    df_plot.set_xlabel("Date")
    df_plot.set_ylabel("Price")
    plt.show()
    
plot_data(df)

# %%
def plot_selected(df, columns, start_index, end_index):
    """Plot the desired columns over index values in the given range."""
    # TODO: Your code here
    # Note: DO NOT modify anything else!
    #Define Range using start:end. Put columns to be selected.
    #df = df.ix[start_index:end_index, columns]
    df = df.loc[start_index:end_index, columns]
    #print(df)
    plot_data(df,title="Selected Tickers")

print(symbols)
df_test = get_data(symbols, dates)
#print(df_test)
plot_selected(df_test, ['AAPL','ABBV','AMZN','BA','BLK','COST','CRM','CRWD','FDX','GOOG','JNJ','JPM','MRVL','MSFT','NFLX','OKTA','TWLO','V'], '1950-01-01', end_date)
# Out:
# ['SPY', 'AAPL', 'ABBV', 'AMZN', 'BA', 'BLK', 'COST', 'CRM', 'CRWD', 'FDX', 'GOOG', 'JNJ', 'JPM', 'MRVL', 'MSFT', 'NFLX', 'OKTA', 'TWLO', 'V']

# %%
#How much the stock went up or down when compared to others. This could be done by normalizing the prices to 1.0
def normalize_stock_prices(df):
    """By dividing the value of each stock by price at day one"""
    #return df / df.ix[0, :]
    return df / df.iloc[0, :]
    #return df / df.loc[0, :]

plot_selected(normalize_stock_prices(df_test), ['AAPL','ABBV','AMZN','BA','BLK','COST','CRM','CRWD','FDX','GOOG','JNJ','JPM','MRVL','MSFT','NFLX','OKTA','TWLO','V'], '1950-01-01', end_date)

# %% [markdown]
# # 2. Numpy Library Drills

# %%
import numpy as np
import time
#print(np.array([(2,3,4),(5,6,7)]))
#Random values from memory location are populated
# print(np.empty(5))
# print(np.empty([5,4]))
# print(np.ones([5,4], dtype=int))
# print(np.random.random([5,4]))
# print(np.random.rand(5,4))
# print(np.random.normal(5,4))
# print(np.random.normal(50, 10, size= (2,3))) ### Mean, STD and nd array dimensions
# print(np.random.randint(10)) #Random between 1 and 10
# print(np.random.randint(0,10)) #Random between 1 and 10
# print(np.random.randint(0,10, size=5)) #5 random integers
# print(np.random.randint(0, 10, size=(2,3))) #2x3 array
a = np.random.random([5,4])
# a.size
print(a.size)
print(a.shape, a.shape[0], a.shape[1], len(a.shape))
print('Data type of a:',a.dtype)
np.random.seed(693)
b = np.random.randint(0, 10, size=(5, 4))
print(b)
# print(b.sum())
# print(b.sum(axis=0)) # sum of rows
# print(b.sum(axis=1)) # sum of columns
# print(b.mean())
t1 = time.time()
a = np.array([9, 6, 2, 3, 12, 14, 7, 10], dtype=np.int32)
print(a.max())
print(a.argmax()) # Index of the maximum value
t2 = time.time()
print("Time", t2-t1)
# e = a[5]
# print(e)
# element = b[3,2]
# print(element)
# print(b[0, 1:3]) #Fetch first row columns 1,2 and exclude 3
# print(b[0, 0:3]) #Fetch first row columns 0,1,2 and exclude 3
# print(b[0, 0:3:2]) #Fetch first row columns 0,2 and exclude 3. Step by 2 elements
# b[0,0] = 2
# print(b)
b[0,:] = 2 #assign first row values as 2
print(b)
b[:, 3] = [1,2,3,4,5] #Assign 3rd columns with values specified 
print(b)

#Indexing in numpy
# x = np.random.random(5)
# indices = np.array([1,1,2,3])
# print('Indices of x:',x[indices])
#Masking
x = np.array([(20,25,10,23,26,32,10,5,0),(0,2,50,20,0,1,28,5,0)])
mean = x.mean()
print('Mean:', mean)
print('Mask:', x[x<mean])

#Arthimetic operations
a = np.array([(1,2,3,4,5), (10,20,30,40,50)])
b = np.array([(100,200,300,400,500),(1,2,3,4,5)])
print('Divide by 2.0\n', a/2.0)
print('\nDivide by 2\n', a/2)
print('\na+b\n', a+b)
print('\na*b\n', a*b)
print('\na/b\n', a/b)
# Out:
# 20
# (5, 4) 5 4 2
# Data type of a: float64
# [[2 0 5 1]
#  [1 3 4 4]
#  [9 2 9 1]
#  [9 3 7 5]
#  [4 7 0 3]]
# 14
# 5
# Time 0.0003712177276611328
# [[2 2 2 2]
#  [1 3 4 4]
#  [9 2 9 1]
#  [9 3 7 5]
#  [4 7 0 3]]
# [[2 2 2 1]
#  [1 3 4 2]
#  [9 2 9 3]
#  [9 3 7 4]
#  [4 7 0 5]]
# Mean: 14.277777777777779
# Mask: [10 10  5  0  0  2  0  1  5  0]
# Divide by 2.0
#  [[ 0.5  1.   1.5  2.   2.5]
#  [ 5.  10.  15.  20.  25. ]]
#
# Divide by 2
#  [[ 0.5  1.   1.5  2.   2.5]
#  [ 5.  10.  15.  20.  25. ]]
#
# a+b
#  [[101 202 303 404 505]
#  [ 11  22  33  44  55]]
#
# a*b
#  [[ 100  400  900 1600 2500]
#  [  10   40   90  160  250]]
#
# a/b
#  [[ 0.01  0.01  0.01  0.01  0.01]
#  [10.   10.   10.   10.   10.  ]]

# %% [markdown]
# # 3. Statistical Analysis (Global and Rolling)

# %%
#Global Statistics. These are not that useful because when companies grow the stock prices go up
mean_df = df.mean()
print('Mean:', mean_df)
median_df = df.median()
print('Median:', median_df)
mode_df = df.mode()
print('Mode:', mode_df)
std_df = df.std()
print('Standard Deviation:', std_df)
variance_df = df.std()**2
print('Variance:', variance_df)
# Out:
# Mean: SPY      302.978442
# AAPL     241.235109
# ABBV      75.850915
# AMZN    1833.154637
# BA       347.994241
# BLK      466.139597
# COST     288.239236
# CRM      158.186566
# CRWD      65.086175
# FDX      156.758215
# GOOG    1256.520662
# JNJ      134.643952
# JPM      121.017417
# MRVL      25.211898
# MSFT     144.418520
# NFLX     314.723854
# OKTA     121.685723
# TWLO     118.195723
# V        181.080176
# dtype: float64
# Median: SPY      297.888000
# AAPL     225.829430
# ABBV      74.997428
# AMZN    1806.119995
# BA       348.751434
# BLK      465.992157
# COST     292.639496
# CRM      156.260002
# CRWD      62.079999
# FDX      157.009094
# GOOG    1239.485046
# JNJ      131.326904
# JPM      117.330822
# MRVL      24.917992
# MSFT     138.762520
# NFLX     309.154999
# OKTA     124.895001
# TWLO     114.724998
# V        178.771225
# dtype: float64
# Mode:             SPY        AAPL       ABBV         AMZN          BA         BLK  \
# 0    289.681458  190.982468  65.331825  1804.660034  325.065948  483.489319
# 1    291.805328  191.576981  68.239571  1855.319946  327.968689  535.239990
# 2    308.035522  192.121979  85.287727          NaN         NaN         NaN
# 3    310.493439  192.379593  86.037590          NaN         NaN         NaN
# 4           NaN  192.419250  87.339996          NaN         NaN         NaN
# ..          ...         ...        ...          ...         ...         ...
# 161         NaN  318.474182        NaN          NaN         NaN         NaN
# 162         NaN  320.688934        NaN          NaN         NaN         NaN
# 163         NaN  323.103180        NaN          NaN         NaN         NaN
# 164         NaN  323.572052        NaN          NaN         NaN         NaN
# 165         NaN  324.440002        NaN          NaN         NaN         NaN
#
#           COST         CRM       CRWD         FDX         GOOG         JNJ  \
# 0    291.25592  149.369995  46.200001  161.977386  1343.560059  129.234833
# 1          NaN         NaN  50.029999         NaN          NaN  131.090073
# 2          NaN         NaN  58.000000         NaN          NaN         NaN
# 3          NaN         NaN  62.240002         NaN          NaN         NaN
# 4          NaN         NaN  66.910004         NaN          NaN         NaN
# ..         ...         ...        ...         ...          ...         ...
# 161        NaN         NaN        NaN         NaN          NaN         NaN
# 162        NaN         NaN        NaN         NaN          NaN         NaN
# 163        NaN         NaN        NaN         NaN          NaN         NaN
# 164        NaN         NaN        NaN         NaN          NaN         NaN
# 165        NaN         NaN        NaN         NaN          NaN         NaN
#
#             JPM       MRVL        MSFT        NFLX        OKTA        TWLO  \
# 0    108.291725  24.344755  134.988449  254.589996   97.059998  103.000000
# 1           NaN        NaN  136.680328  263.079987   98.459999  132.050003
# 2           NaN        NaN  137.276642  263.309998   98.559998         NaN
# 3           NaN        NaN  137.593704  264.750000   99.290001         NaN
# 4           NaN        NaN  138.250671  265.920013  100.790001         NaN
# ..          ...        ...         ...         ...         ...         ...
# 161         NaN        NaN         NaN  379.500000  137.119995         NaN
# 162         NaN        NaN         NaN  379.929993  138.020004         NaN
# 163         NaN        NaN         NaN  380.549988  138.070007         NaN
# 164         NaN        NaN         NaN  381.000000  138.660004         NaN
# 165         NaN        NaN         NaN  381.720001  140.529999         NaN
#
#               V
# 0    174.335083
# 1    178.493744
# 2    179.179962
# 3    179.748016
# 4           NaN
# ..          ...
# 161         NaN
# 162         NaN
# 163         NaN
# 164         NaN
# 165         NaN
#
# [166 rows x 19 columns]
# Standard Deviation: SPY      14.199164
# AAPL     40.448430
# ABBV      9.210776
# AMZN     83.355488
# BA       18.583021
# BLK      37.550580
# COST     13.896073
# CRM      11.479243
# CRWD     14.840899
# FDX       8.034544
# GOOG    107.561728
# JNJ       7.440294
# JPM      11.514564
# MRVL      1.302912
# MSFT     11.602242
# NFLX     32.082312
# OKTA     10.928794
# TWLO     16.635738
# V         9.094319
# dtype: float64
# Variance: SPY       201.616248
# AAPL     1636.075466
# ABBV       84.838395
# AMZN     6948.137341
# BA        345.328654
# BLK      1410.046044
# COST      193.100845
# CRM       131.773029
# CRWD      220.252291
# FDX        64.553890
# GOOG    11569.525299
# JNJ        55.357982
# JPM       132.585173
# MRVL        1.697581
# MSFT      134.612019
# NFLX     1029.274769
# OKTA      119.438534
# TWLO      276.747785
# V          82.706633
# dtype: float64

# %% [markdown]
# ## Rolling Statistics and Bollinger Bands

# %%
# Rolling Statistics - Collected on a time series window. Duration of days etc. 200 day moving average is an example
# Rolling mean also called moving average is common technical indicator. Rolling Standard Deviation and Bollinger bands show how significant is the deviation observed.
def symbol_to_path(symbol, base_dir="../data"):
    """Return CSV file path given ticker symbol."""
    return os.path.join(base_dir, "{}.csv".format(str(symbol)))


def get_data(symbols, dates):
    """Read stock data (adjusted close) for given symbols from CSV files."""
    df = pd.DataFrame(index=dates)
    if 'SPY' not in symbols:  # add SPY for reference, if absent
        symbols.insert(0, 'SPY')

    for symbol in symbols:
        df_temp = pd.read_csv(symbol_to_path(symbol), index_col='Date',
                parse_dates=True, usecols=['Date', 'Adj Close'], na_values=['nan'])
        df_temp = df_temp.rename(columns={'Adj Close': symbol})
        df = df.join(df_temp)
        if symbol == 'SPY':  # drop dates SPY did not trade
            df = df.dropna(subset=["SPY"])

    return df


def plot_data(df, title="Stock prices"):
    """Plot stock prices with a custom title and meaningful axis labels."""
    ax = df.plot(title=title, fontsize=12)
    ax.set_xlabel("Date")
    ax.set_ylabel("Price")
    plt.show()


def get_rolling_mean(values, window):
    """Return rolling mean of given values, using specified window size."""
    series = pd.Series(values)
    return series.rolling(window).mean()


def get_rolling_std(values, window):
    """Return rolling standard deviation of given values, using specified window size."""
    # TODO: Compute and return rolling standard deviation
    series = pd.Series(values)
    return series.rolling(window).std()
    


def get_bollinger_bands(rm, rstd):
    """Return upper and lower Bollinger Bands."""
    # TODO: Compute upper_band and lower_band
    lower_band = rm - rstd*2
    upper_band = rm + rstd*2
    return upper_band, lower_band


def test_run():
    # Read data
    dates = pd.date_range('1950-01-01', end_date)
    symbols = ['AAPL','ABBV','AMZN','BA','BLK','COST','CRM','CRWD','FDX','GOOG','JNJ','JPM','MRVL','MSFT','NFLX','OKTA','TWLO','V']
    df = get_data(symbols, dates)
    
    for symbol in symbols:
        # Compute Bollinger Bands
        # 1. Compute rolling mean
        rm_symbol = get_rolling_mean(df[symbol], window=20)
        
        # 2. Compute rolling standard deviation
        rstd_symbol = get_rolling_std(df[symbol], window=20)
        
        # 3. Compute upper and lower bands
        upper_band, lower_band = get_bollinger_bands(rm_symbol, rstd_symbol)
        
        # Plot raw rolling mean and Bollinger Bands
        ax = df[symbol].plot(title="Bollinger Bands", label=symbol)
        rm_symbol.plot(label='Rolling mean', ax=ax)
        upper_band.plot(label='upper band', ax=ax)
        lower_band.plot(label='lower band', ax=ax)
        
        # Add axis labels and legend
        ax.set_xlabel("Date")
        ax.set_ylabel("Price")
        ax.legend(loc='upper left')
        plt.show()

#     # Compute Bollinger Bands
#     # 1. Compute rolling mean
#     #rm_SPY = get_rolling_mean(df['SPY'], window=20)
#     rm_SPY = get_rolling_mean(df['AMZN'], window=20)

#     # 2. Compute rolling standard deviation
#     #rstd_SPY = get_rolling_std(df['SPY'], window=20)
#     rstd_SPY = get_rolling_std(df['AMZN'], window=20)

#     # 3. Compute upper and lower bands
#     upper_band, lower_band = get_bollinger_bands(rm_SPY, rstd_SPY)
    
#     # Plot raw SPY values, rolling mean and Bollinger Bands
#     ax = df['AMZN'].plot(title="Bollinger Bands", label='AMZN')
#     rm_SPY.plot(label='Rolling mean', ax=ax)
#     upper_band.plot(label='upper band', ax=ax)
#     lower_band.plot(label='lower band', ax=ax)

#     # Add axis labels and legend
#     ax.set_xlabel("Date")
#     ax.set_ylabel("Price")
#     ax.legend(loc='upper left')
#     plt.show()
    
#     # Compute Bollinger Bands
#     # 1. Compute rolling mean
#     rm_SPY = get_rolling_mean(df['SPY'], window=20)
    
#     # 2. Compute rolling standard deviation
#     rstd_SPY = get_rolling_std(df['SPY'], window=20)

#     # 3. Compute upper and lower bands
#     upper_band, lower_band = get_bollinger_bands(rm_SPY, rstd_SPY)
    
#     # Plot raw SPY values, rolling mean and Bollinger Bands
#     ax = df['SPY'].plot(title="Bollinger Bands", label='SPY')
#     rm_SPY.plot(label='Rolling mean', ax=ax)
#     upper_band.plot(label='upper band', ax=ax)
#     lower_band.plot(label='lower band', ax=ax)

#     # Add axis labels and legend
#     ax.set_xlabel("Date")
#     ax.set_ylabel("Price")
#     ax.legend(loc='upper left')
#     plt.show()
    
#     # Compute Bollinger Bands
#     # 1. Compute rolling mean
#     rm_SPY = get_rolling_mean(df['JNJ'], window=20)
    
#     # 2. Compute rolling standard deviation
#     rstd_SPY = get_rolling_std(df['JNJ'], window=20)

#     # 3. Compute upper and lower bands
#     upper_band, lower_band = get_bollinger_bands(rm_SPY, rstd_SPY)
    
#     # Plot raw SPY values, rolling mean and Bollinger Bands
#     ax = df['JNJ'].plot(title="Bollinger Bands", label='JNJ')
#     rm_SPY.plot(label='Rolling mean', ax=ax)
#     upper_band.plot(label='upper band', ax=ax)
#     lower_band.plot(label='lower band', ax=ax)


if __name__ == "__main__":
    test_run()

# %% [markdown]
# ## Daily Returns

# %%
# daily_returns = df.copy()
# daily_returns[1:] = (df[1:] / df[:-1].values) - 1
# daily_returns.iloc[0, :] = 0
#symbols = ['AAPL','ABBV','AMZN','BA','BLK','COST','CRM','CRWD','FDX','GOOG','JNJ','JPM','MRVL','MSFT','NFLX','OKTA','TWLO','V']
def plot_data(df, title="Stock prices", xlabel="Date", ylabel="Price"):
    """Plot stock prices with a custom title and meaningful axis labels."""
    ax = df.plot(title=title, fontsize=12)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    plt.show()

# Using Pandas Data Frame
def compute_daily_returns(df):
    """Compute and return the daily return values."""
    # TODO: Your code here
    # Note: Returned DataFrame must have the same number of rows
    daily_returns = (df / df.shift(1)) - 1
    daily_returns.iloc[0, :] = 0
    return daily_returns

def test_run():
    # Read data
    dates = pd.date_range('1950-01-01', end_date)  # one month only
    symbols = ['AAPL','ABBV','AMZN','BA','BLK','COST','CRM','CRWD','FDX','GOOG','JNJ','JPM','MRVL','MSFT','NFLX','OKTA','TWLO','V']
    df = get_data(symbols, dates)
    plot_data(df)

    # Compute daily returns
    daily_returns = compute_daily_returns(df)
    plot_data(daily_returns, title="Daily returns", ylabel="Daily returns")


if __name__ == "__main__":
    test_run()

# %% [markdown]
# ## Cumulative Returns (***TBD Correct Cumulative***)

# %%
# Using Pandas Data Frame
def compute_cumulative_returns(df):
    """Compute and return the daily return values."""
    # TODO: Your code here
    # Note: Returned DataFrame must have the same number of rows
    cum_returns = df.copy()
    cum_returns[1:] = (df[1:] / df[:-1].values) - 1 # How to get cummulative returns
    cum_returns.iloc[0, :] = 0
    return cum_returns

def test_run():
    # Read data
    dates = pd.date_range('1950-01-01', end_date)  # one month only
    symbols = ['AAPL','ABBV','AMZN','BA','BLK','COST','CRM','CRWD','FDX','GOOG','JNJ','JPM','MRVL','MSFT','NFLX','OKTA','TWLO','V']
    df = get_data(symbols, dates)
    plot_data(df)

    # Compute cumulative returns
    cum_returns = compute_cumulative_returns(df)
    plot_data(cum_returns, title="Cumulative returns", ylabel="Cumulative returns")


if __name__ == "__main__":
    test_run()

# %% [markdown]
# ## Incomplete Data Handling

# %%
"""Fill missing values"""

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

def fill_missing_values(df_data):
    """Fill missing values in data frame, in place."""
    ##########################################################
    #pass  # TODO: Your code here (DO NOT modify anything else)
    ##########################################################
    # df_data.fillna(method='ffill')
    df_data.fillna(method="ffill", inplace=True) 
    df_data.fillna(method="bfill", inplace=True) 


def symbol_to_path(symbol, base_dir="../data"):
    """Return CSV file path given ticker symbol."""
    return os.path.join(base_dir, "{}.csv".format(str(symbol)))


def get_data(symbols, dates):
    """Read stock data (adjusted close) for given symbols from CSV files."""
    df_final = pd.DataFrame(index=dates)
    if "SPY" not in symbols:  # add SPY for reference, if absent
        symbols.insert(0, "SPY")

    for symbol in symbols:
        file_path = symbol_to_path(symbol)
        df_temp = pd.read_csv(file_path, parse_dates=True, index_col="Date",
            usecols=["Date", "Adj Close"], na_values=["nan"])
        df_temp = df_temp.rename(columns={"Adj Close": symbol})
        df_final = df_final.join(df_temp)
        if symbol == "SPY":  # drop dates SPY did not trade
            df_final = df_final.dropna(subset=["SPY"])

    return df_final


def plot_data(df_data):
    """Plot stock data with appropriate axis labels."""
    ax = df_data.plot(title="Stock Data", fontsize=2)
    ax.set_xlabel("Date")
    ax.set_ylabel("Price")
    plt.show()


def test_run():
    """Function called by Test Run."""
    # Read data
#     symbol_list = ["AMZN", "JNJ", "SPY"]  # list of symbols
    symbol_list = symbols = ['AAPL','ABBV','AMZN','BA','BLK','COST','CRM','CRWD','FDX','GOOG','JNJ','JPM','MRVL','MSFT','NFLX','OKTA','TWLO','V']
    start_date = "1950-01-01"
    #end_date = "2014-12-07"
    dates = pd.date_range(start_date, end_date)  # date range as index
    df_data = get_data(symbol_list, dates)  # get data for each symbol

    # Fill missing values
    fill_missing_values(df_data)

    # Plot
    plot_data(df_data)


if __name__ == "__main__":
    test_run()

# %% [markdown]
# ## Daily Returns - Histograms - Price and Time Series/Daily Return and Time Series

# %%
# Plotting histograms and Kurtosis
def set_end_date():
    return date(date.today().year, date.today().month, date.today().day)

def test_run():
    """Function called by Test Run."""
    # Read data
    symbol_list = ["AMZN", "JNJ", "SPY"]  # list of symbols
    symbol_list = symbols = ['AAPL','ABBV','AMZN','BA','BLK','COST','CRM','CRWD','FDX','GOOG','JNJ','JPM','MRVL','MSFT','NFLX','OKTA','TWLO','V']
    #symbol_list = ["SPY"]  # list of symbols
    start_date = "2018-01-01"
    end_date = set_end_date()
    dates = pd.date_range(start_date, end_date)  # date range as index
    df_data = get_data(symbol_list, dates)  # get data for each symbol

    # Fill missing values
    fill_missing_values(df_data)

    # Plot
    #plot_data(df_data)
    # Compute daily returns
    daily_returns = compute_daily_returns(df_data)
    #df_data['daily_return'] = daily_returns
    #plot_data(daily_returns, title="Daily returns", ylabel="Daily returns")
    
    #Plot Histogram
#     daily_returns.hist(bins=20)
    
#     #Get mean and standard deviation of daily returns
#     dr_mean = daily_returns['SPY'].mean()
#     #dr_mean = daily_returns.mean()
#     print('Mean: ', dr_mean)
#     dr_std = daily_returns['SPY'].std()
#     #dr_std = daily_returns.std()
#     print('STD: ', dr_std)
    
#     #Plot both mean and standard deviations
#     plt.axvline(dr_mean,color='orange',linestyle='dashed',linewidth=2)
#     plt.axvline(dr_std,color='red',linestyle='dashed',linewidth=2)
#     plt.axvline(-dr_std,color='red',linestyle='dashed',linewidth=2)
#     plt.show()
    
#     #Compute Kurtosis
#     print('Kurtosis:', daily_returns.kurtosis())
    #print(daily_returns)
    #print(df_data)
    daily_returns['SPY'].hist(bins=20, label='SPY')
    daily_returns['AMZN'].hist(bins=20, label='AMZN')
    #daily_returns['JNJ'].hist(bins=20, label='JNJ')
    plt.legend(loc='upper right')
    
    #Scatter plot AMZN vs SPY
    daily_returns.plot(kind='scatter',x='SPY',y='AMZN')
    #Fit polynomial
    beta_AMZN, alpha_AMZN = np.polyfit(daily_returns['SPY'], daily_returns['AMZN'], 1)
    plt.plot(daily_returns['SPY'], beta_AMZN*daily_returns['SPY']+alpha_AMZN, '-', color='r')
    plt.show()
    
    daily_returns.plot(kind='scatter',x='SPY',y='JNJ')
    beta_JNJ, alpha_JNJ = np.polyfit(daily_returns['SPY'], daily_returns['JNJ'], 1)
    plt.plot(daily_returns['SPY'], beta_JNJ*daily_returns['SPY']+alpha_JNJ, '-', color='r')
    plt.show()
    print('Kurtosis:', daily_returns.kurtosis())
    print('Beta AMZN:', beta_AMZN)
    print('Beta JNJ:', beta_JNJ)
    print('Alpha AMZN:', alpha_AMZN)
    print('Alpha AMZN:', alpha_JNJ)
    print(daily_returns.corr(method='pearson'))


if __name__ == "__main__":
    test_run()
# Out:
# Kurtosis: SPY      3.769131
# AAPL     3.795413
# ABBV    16.702368
# AMZN     3.313274
# BA       1.224652
# BLK      2.090478
# COST     7.171606
# CRM      3.342120
# CRWD     9.703159
# FDX      8.224773
# GOOG     4.968617
# JNJ     11.938708
# JPM      1.530972
# MRVL     0.742633
# MRVL  0.452205  0.098939  0.479742  0.480154  0.207684  0.448228  1.000000
# MSFT  0.736012  0.159813  0.461587  0.734318  0.389194  0.552570  0.521422
# NFLX  0.600660  0.062934  0.338137  0.556291  0.266496  0.380750  0.414415
# OKTA  0.637358  0.224240  0.214063  0.434663  0.181500  0.199409  0.330318
# TWLO  0.645735  0.163188  0.256183  0.482962  0.189865  0.279023  0.350741
# V     0.733473  0.103030  0.453084  0.683515  0.352598  0.523510  0.483387
#
#           MSFT      NFLX      OKTA      TWLO         V
# SPY   0.846704  0.611916  0.482757  0.526576  0.805328
# AAPL  0.666353  0.471195  0.406593  0.424962  0.637833
# ABBV  0.413423  0.253544  0.228600  0.223231  0.377497
# AMZN  0.729654  0.642775  0.498095  0.538331  0.655932
# BA    0.484963  0.378536  0.272811  0.268575  0.456653
# BLK   0.625702  0.428115  0.306645  0.374315  0.606969
# COST  0.517614  0.363475  0.294224  0.326449  0.479906
# CRM   0.736012  0.600660  0.637358  0.645735  0.733473
# CRWD  0.159813  0.062934  0.224240  0.163188  0.103030
# FDX   0.461587  0.338137  0.214063  0.256183  0.453084
# GOOG  0.734318  0.556291  0.434663  0.482962  0.683515
# JNJ   0.389194  0.266496  0.181500  0.189865  0.352598
# JPM   0.552570  0.380750  0.199409  0.279023  0.523510
# MRVL  0.521422  0.414415  0.330318  0.350741  0.483387
# MSFT  1.000000  0.600222  0.506996  0.552531  0.800749
# NFLX  0.600222  1.000000  0.428027  0.448037  0.559796
# OKTA  0.506996  0.428027  1.000000  0.669384  0.568127
# TWLO  0.552531  0.448037  0.669384  1.000000  0.549469
# V     0.800749  0.559796  0.568127  0.549469  1.000000

# %% [markdown]
# ## Portfolio Statistics and Sharpe Ratio

# %%
# ****Theory Cell***
# LIBOR, 3 Month T-Bill or 0% are used as basis for risk free rate.
# Sharpe Ratio s = E(Rp - Rf)/std[Rp-Rf]. In Python: s = mean(daily_returns - daily_riskfreerate)/std(daily_returns - daily_riskfreerate)
# s = mean(daily_returns - daily_riskfreerate)/std(daily_returns) - Formula used
# Risk free rate 10% - Interest day per day = number of working ways root of 1.0 + 0.1 -1
# sr_annulaized = k * sr (k = adjustment factor) k = sqrt(number of samples per year)
# daily_k = sqrt(252), weekly_k = sqrt(52), monthly_k = sqrt(12)

# %%
import math
sr = (0.001 - 0.0002)/0.001
#sr = ((10-2)/10)
print(sr*math.sqrt(252))
#Cumulative Return, Avg. Daily Return, Risk (also called std of daily return) or Sharpe Ratio

# import numpy as np

# # daily return:
# df['daily_return'] = df['close'].pct_change()

# # calculate cumluative return
# df['cumluative_return'] = np.exp(np.log1p(df['daily_return']).cumsum())
# np.cumprod(1 + df['Daily_rets'].values) - 1
# df['perc_ret'] = (1 + df.Daily_rets).cumprod() - 1  # Or df.Daily_rets.add(1).cumprod().sub(1)
# Out:
# 12.699606293110037

# %% [markdown]
# ## Calculation Of Average Daily Returns, Cumulative Returns, Risk and Sharpe Ratio

# %%
def compute_risk(daily_returns):
    return daily_returns.std()

def compute_volatility(daily_returns):
    return daily_returns.std()

def compute_cumulative_returns(df):
    """Compute and return the daily return values."""
    # TODO: Your code here
    # cum_return(val[-1]/val[0]) - 1
    # Note: Returned DataFrame must have the same number of rows
    # How to get cummulative returns
    # Step 1: Make a copy of data frame
    cum_returns = df.copy()
    # Step 2: Find Daily Returns first
    daily_returns = (df[1:] / df[:-1].values) - 1 
    
    # Step 3: Find Cumulative sum using numpy function
    cum_returns = np.exp(np.log1p(daily_returns).cumsum())
    cum_returns.iloc[0, :] = 0
    return cum_returns

# Risk reward and Sharpe Ratio
def compute_risk_reward(daily_ret, risk_free_ret, start_date, end_date):
    number_of_trading_days = np.busday_count(start_date,end_date)
    sharpe_ratio = ((daily_returns.mean() - daily_risk_free_rate)/risk)*math.sqrt(number_of_trading_days)
    return sharpe_ratio
    
def test_run():
    """Function called by Test Run."""
    # Read data
    symbol_list = ["AMZN", "JNJ", "SPY","AAPL","UTX"]  # list of symbols
    symbol_list = symbols = ['AAPL','ABBV','AMZN','BA','BLK','COST','CRM','CRWD','FDX','GOOG','JNJ','JPM','MRVL','MSFT','NFLX','OKTA','TWLO','V','XOM']
    #symbol_list = ["SPY"]  # list of symbols
    start_date = "2018-01-01"
    end_date = set_end_date()
    dates = pd.date_range(start_date, end_date)  # date range as index
    df_data = get_data(symbol_list, dates)  # get data for each symbol

    # Fill missing values
    fill_missing_values(df_data)

    # Plot
    #plot_data(df_data)
    # 0. Compute Daily Returns
    daily_returns = compute_daily_returns(df_data)
    print("***Daily Returns****")
    print(daily_returns)
    
    # 1. Compute cumulative returns
    cumulative_returns = compute_cumulative_returns(df_data)
    print("***Cumulative Returns****")
    print(cumulative_returns)
    
    # 2. Compute risk - Standard deviation of daily returns 
    print("***Risk****")
    risk = compute_risk(daily_returns)
    print(risk)
    
    # 3. Sharpe Ratio -  Formula given below:
    # sharpe ratio s = mean(daily_returns - daily_riskfreerate)/std(daily_returns - daily_riskfreerate)
    # Formula used in this notebook: sharpe ratio s = mean(daily_returns - daily_riskfreerate)/std(daily_returns)
    # Multiply Square Root of number of working days between start_date and end_date with sharpe ratio calculated above
    # to get annualized sharpe ratio
    daily_risk_free_rate = 0.0
    # Use Numpy to calculate number of business days between two dates
    business_days = np.busday_count(start_date,end_date)
    print("Business Days:", business_days)
    number_of_trading_days = business_days #252+(252/2) #Number of trading days in 2018 and 2019(so far)
    sharpe_ratio = ((daily_returns.mean() - daily_risk_free_rate)/risk)*math.sqrt(number_of_trading_days)
    print("***Sharpe Ratios***")
    print(sharpe_ratio)
    


if __name__ == "__main__":
    test_run()
# Out:
# ***Daily Returns****
#                  SPY      AAPL      ABBV      AMZN        BA       BLK  \
# 2018-01-02  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2018-01-03  0.006325 -0.000174  0.015649  0.012775  0.003234  0.010551
# 2018-01-04  0.004215  0.004645 -0.005703  0.004476 -0.003794  0.013201
# 2018-01-05  0.006664  0.011385  0.017408  0.016163  0.041022  0.008520
# 2018-01-08  0.001829 -0.003714 -0.016022  0.014425  0.004242  0.007458
# ...              ...       ...       ...       ...       ...       ...
# 2020-01-